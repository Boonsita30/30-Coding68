# %% [markdown]
# <a href="https://colab.research.google.com/github/Boonsita30/30-Coding68/blob/main/mid_30_BAIBUA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#สอบกลางภาคเทอม 2
name=input("ยินดีต้อนรับค่า! ผู้ใชชื่ออะไรค่ะ")
print("ยินดีต้อนรับเข้าสู่โปรแกรมคำนวณค่ากรด/เบส\n")

acid = int(input("acid 0-14 <7:"))
mediem = int(input("mediem =7"))
bass = int(input("bass >7"))

print("\nสรุปผลกรด/เบส:")

if acid < 7:
  print("กรด")
elif mediem < 7:
  print("เป็นกลาง")
elif aver >=7:
  print("เบส")
else:
  print("การคำนวณของคุณสำเร็จแล้ว")
